# %%
# UNCOMMENT AND RUN IF NECESSARY
# !pip install pandas numpy matplotlib seaborn ipywidgets ipympl

# %%
from prototype_data import PrototypeData
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import ipywidgets as widgets

# %%
# METADATA

num_rows = 1000 #how many records to generate
proto = PrototypeData(locale="en_CA", seed=47) #initialize the PrototypeData class with a seed for reproducibility

# %%
# GENERATE MOCK DATA

mock_df = pd.DataFrame({
    "Name": [proto.fake_name() for _ in range(num_rows)],
    "Address": [proto.fake_address() for _ in range(num_rows)],
    "Email": [proto.fake_email() for _ in range(num_rows)],
    "Income": np.round(proto.generate_distribution("right-skew", num_rows, mean=10, sigma=0.5, target_mean=55000), 2),
    "Height_cm": np.round(proto.generate_distribution("normal", num_rows, loc=170, scale=10), 1),
    "Easy_Test_Score": np.round(proto.generate_distribution("left-skew", num_rows, mean=10, sigma=0.5, max_value=100, target_mean=85), 1)
})

# Jupyter auto-display
mock_df
# Out:
#                   Name                                            Address  \
# 0         David Wilson  91607 Rachel Alley Suite 187\nNorth Amandamout...
# 1      Melissa Clayton  63368 Carroll Shore Apt. 979\nArmstrongfort, Y...
# 2    Christine Johnson          110 Robin Islands\nAndreafurt, ON A4Y 4S4
# 3      Daniel Anderson             9668 Brown Union\nAlecview, PE S5V 5P7
# 4       Stephen Deleon      6137 Hill Ville\nLake Patricialand, NL N5R8J5
# ..                 ...                                                ...
# 995       Carmen Nunez       376 George Forge\nNew Michaelfort, NS R1R5A2
# 996      James Hopkins     4852 Roy Dam Suite 857\nEast Joseph, YT M6P8A1
# 997          Lori Levy  67459 Rivera Burgs Apt. 306\nSouth Tiffany, NU...
# 998       Samuel Walsh  789 Kline Plaza Suite 163\nLake Jasonbury, NL ...
# 999      Bobby Griffin  98894 Brittany Groves Suite 154\nCrystalberg, ...
#
#                             Email    Income  Height_cm  Easy_Test_Score
# 0      schmidtbrandon@example.net  22337.70      167.9             91.7
# 1            dustin54@example.net  76208.59      150.2             92.1
# 2            fpittman@example.com  37162.35      187.5             89.3
# 3            ajackson@example.org  59199.17      165.1             90.9
# 4          bauerjason@example.com  76862.05      189.2             93.8
# ..                            ...       ...        ...              ...
# 995           peter16@example.net  14600.18      157.5             73.4
# 996          meagan91@example.net  65225.91      168.2             82.0
# 997      douglassusan@example.com  22751.97      183.1             97.6
# 998  feliciaschneider@example.org  40317.29      153.4             96.5
# 999      debrashaffer@example.net  55583.45      185.7             85.9
#
# [1000 rows x 6 columns]

# %%
#VISUALIZE DATA

# Create dropdown widget with numeric columns only
numeric_cols = mock_df.select_dtypes(include=np.number).columns.tolist()
dropdown = widgets.Dropdown(
    options=numeric_cols,
    value=numeric_cols[0],
    description='Select Column:',
)

# Function to plot histogram
def plot_histogram(column):
    plt.figure(figsize=(10,5))
    sns.histplot(mock_df[column], bins=30, kde=True, color="skyblue")
    plt.title(f"Distribution of {column}")
    plt.xlabel(column)
    plt.ylabel("Count")
    plt.show()

# Link dropdown to plotting function
widgets.interact(plot_histogram, column=dropdown)
# Out:
# interactive(children=(Dropdown(description='Select Column:', options=('Income', 'Height_cm', 'Easy_Test_Score'…
# <function __main__.plot_histogram(column)>
